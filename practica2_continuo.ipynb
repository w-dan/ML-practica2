# %% [markdown]
# <a href="https://colab.research.google.com/github/w-dan/ML-practica2/blob/main/practica2_continuo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importación de librerías

import numpy as np
import pandas as pd
import sklearn.compose as Compose
import math

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
train_url = "https://raw.githubusercontent.com/Kekon130/ML_Practica2/main/train.csv"
df_train = pd.read_csv(train_url)

test_url = "https://raw.githubusercontent.com/Kekon130/ML_Practica2/main/test.csv"
df_test = pd.read_csv(test_url)

#pd.set_option('display.max_columns', None)
df_train
# Out:
#            ID  Customer_ID  Month               Name   Age          SSN  \
# 0       43161         3985      4          Lawrencez  40.0  856431180.0
# 1       40663        49494      2          Mohammedr  39.0  417453942.0
# 2      111059         2925      6          Alistairn  17.0  499528888.0
# 3       72139        21358      2       Dinesh Naire  22.0  859449371.0
# 4      119841        21221      4             Bakerg  26.0  485239890.0
# ...       ...          ...    ...                ...   ...          ...
# 79995   42636        39869      7  Hendrik Sackmannb  50.0  217529489.0
# 79996  114031        38305      2              Alexj  33.0   98861902.0
# 79997   85991         9976      6     Luciana Lopezi  25.0  745835485.0
# 79998   21240        13193      7      Edward Krudyd  15.0  894419091.0
# 79999   73558        15294      5              Neilp  30.0   17531609.0
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0         Accountant       97384.44            8167.370000                1.0
# 1             Writer       31369.58            2607.131667                8.0
# 2             Writer       30171.86            2772.321667                6.0
# 3             Doctor       13100.02            1246.668333                7.0
# 4             Doctor       62313.54            5120.795000                6.0
# ...              ...            ...                    ...                ...
# 79995  Media_Manager      107761.29            9047.107500                4.0
# 79996      Scientist       16218.32            1098.526667                6.0
# 79997       Engineer       29374.77            2377.897500                3.0
# 79998        Manager       43782.45            3543.537500                6.0
# 79999         Lawyer      102215.61            8482.967500                2.0
#
#        ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0      ...        Good            405.45                 32.643281
# 1      ...         Bad           4259.91                 39.375507
# 2      ...         Bad           3406.51                 34.039021
# 3      ...    Standard            727.29                 34.747262
# 4      ...    Standard            817.64                 24.545394
# ...    ...         ...               ...                       ...
# 79995  ...    Standard             34.09                 41.899992
# 79996  ...         Bad           4466.33                 24.275710
# 79997  ...    Standard           1189.37                 38.439021
# 79998  ...         Bad           3468.25                 24.233841
# 79999  ...        Good             79.67                 27.903216
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                  336.0                     No            77.284943
# 1                  144.0                    Yes           171.748418
# 2                  123.0                    Yes           205.403926
# 3                  129.0                    Yes            41.177132
# 4                  122.0                     NM           196.679642
# ...                  ...                    ...                  ...
# 79995              211.0                    Yes             0.000000
# 79996               98.0                     NM            64.533114
# 79997              241.0                     NM            40.264074
# 79998               85.0                    Yes           240.664739
# 79999              366.0                     No            60.567361
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    53.714219   High_spent_Large_value_payments
# 1                    44.990811   High_spent_Large_value_payments
# 2                    40.781489   High_spent_Large_value_payments
# 3                    23.005463    Low_spent_Large_value_payments
# 4                    63.346750   Low_spent_Medium_value_payments
# ...                        ...                               ...
# 79995               150.220682   High_spent_Large_value_payments
# 79996                34.457893   High_spent_Small_value_payments
# 79997                22.234178  High_spent_Medium_value_payments
# 79998                42.839562    Low_spent_Large_value_payments
# 79999                60.971467   Low_spent_Medium_value_payments
#
#       Monthly_Balance  Credit_Score
# 0          847.172909      Standard
# 1          280.855383      Standard
# 2          247.322615      Standard
# 3          298.156832      Standard
# 4          152.669902      Standard
# ...               ...           ...
# 79995      984.123010      Standard
# 79996      260.523798          Poor
# 79997      403.980355      Standard
# 79998      146.741586          Poor
# 79999      355.384222          Good
#
# [80000 rows x 28 columns]

# %% [markdown]
# ## Analizando las columnas

# %%
# Customer ID. 
# Esta se deja tal cual y no se toca, la necesitamos

# %%
def transformar_valores(columna, decimal):
  for index, row in df_train.iterrows():
    df_train.loc[index, columna] = round(df_train.loc[index, columna], decimal)

"""
transformar_valores("Annual_Income", -4)
transformar_valores("Monthly_Inhand_Salary", -3)
transformar_valores("Changed_Credit_Limit", -1)
transformar_valores("Outstanding_Debt", -2)
transformar_valores("Credit_Utilization_Ratio", 1)
transformar_valores("Total_EMI_per_month", -1)
transformar_valores("Amount_invested_monthly", -1)
transformar_valores("Monthly_Balance", -2)
"""
# Out:
# '\ntransformar_valores("Annual_Income", -4)\ntransformar_valores("Monthly_Inhand_Salary", -3)\ntransformar_valores("Changed_Credit_Limit", -1)\ntransformar_valores("Outstanding_Debt", -2)\ntransformar_valores("Credit_Utilization_Ratio", 1)\ntransformar_valores("Total_EMI_per_month", -1)\ntransformar_valores("Amount_invested_monthly", -1)\ntransformar_valores("Monthly_Balance", -2)\n'

# %%
# Month
# Representa el mes del año en el que se actualizó la información

# Podemos ver cómo el mes no influye casi nada, los valores están prácticamente igual repartidos 
plot = pd.crosstab(index=df_train['Month'],
            columns=df_train["Credit_Score"]
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True, color=['#dede00', '#e41a1c', '#999999'])

# %%
# Name
# Esta variable la vamos a borrar, ya que tiene bastantes menos valores que el Customer_ID y ello puede dar problemas para el tratamiento posterior. Además no nos aporta nada.

# %%
# Age
# Edad -> Clasificar en tres grupos (va desde los 14 años hasta los 59)        juventud (14 - 26)           adultez (27 - 40)          otro (41 - 59)

# Vemos la realcion de edad con la bariable objetivosss
y = df_train["Credit_Score"]


# Malos: Son terribles desde los 18 a los 45 años, en ese rango de valores hay un huevo de malos, Luego a partir de los 46 años baja dráticamante el número, aunque esto puede estar ligado a que haya menos datos sobre este sector de edad, tendremos que revisar eso
# Estándar: La proporcion es muy parecida a los malos, a partir de los 45 varía bastante el numero
# Bueno: En este caso se mantiene estable a partir de los 18 años hasta el final

# %%
# SNN
df_train.Customer_ID.nunique()
df_train.SSN.nunique()                                  # La seguridad social la vamos a borrar entonces

# Ambos devuelven tienen el mismo numero, vamos, que cada uno va ligado a un mismo cliente.
# Out:
# 12500

# %%
# Occupation
output = pd.crosstab(df_train["Credit_Score"], df_train["Occupation"])
output

plot = pd.crosstab(index=df_train['Occupation'],
            columns=df_train["Credit_Score"]
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True, color=['#dede00', '#e41a1c', '#999999'])

# Es bastante estable en todos los campos

# %% [markdown]
# ## Preprocesamiento

# %%
df_train = df_train.drop('Month', axis=1)
df_train = df_train.drop('Name', axis=1)
df_train = df_train.drop('SSN', axis=1)
df_train = df_train.drop('Occupation', axis=1)
df_train = df_train.drop('ID', axis=1)
df_train = df_train.drop('Customer_ID', axis=1)
df_train = df_train.drop('Credit_Score', axis=1)
df_train = df_train.drop('Age', axis=1)

# %%
df_train
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0           97384.44            8167.370000                1.0
# 1           31369.58            2607.131667                8.0
# 2           30171.86            2772.321667                6.0
# 3           13100.02            1246.668333                7.0
# 4           62313.54            5120.795000                6.0
# ...              ...                    ...                ...
# 79995      107761.29            9047.107500                4.0
# 79996       16218.32            1098.526667                6.0
# 79997       29374.77            2377.897500                3.0
# 79998       43782.45            3543.537500                6.0
# 79999      102215.61            8482.967500                2.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3.0            8.0          1.0
# 1                  9.0           27.0          8.0
# 2                  7.0           30.0          9.0
# 3                  5.0            6.0          5.0
# 4                  2.0           18.0          4.0
# ...                ...            ...          ...
# 79995              5.0            9.0          0.0
# 79996              6.0           21.0          5.0
# 79997              7.0            6.0          2.0
# 79998              9.0           25.0          8.0
# 79999              5.0           10.0          1.0
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 0                                Debt Consolidation Loan                 20.0
# 1      Home Equity Loan, Not Specified, Not Specified...                 30.0
# 2      Personal Loan, Home Equity Loan, Home Equity L...                 49.0
# 3      Credit-Builder Loan, Credit-Builder Loan, Not ...                  6.0
# 4      Auto Loan, Payday Loan, Student Loan, and Cred...                 27.0
# ...                                                  ...                  ...
# 79995                                            No Data                  7.0
# 79996  Mortgage Loan, Home Equity Loan, Credit-Builde...                 44.0
# 79997                      Student Loan, and Payday Loan                 23.0
# 79998  Payday Loan, Auto Loan, Payday Loan, Home Equi...                 32.0
# 79999                                      Mortgage Loan                 11.0
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                        12.0                  0.52                   3.0
# 1                        25.0                 19.70                   6.0
# 2                        18.0                 23.49                  10.0
# 3                        20.0                 10.64                   8.0
# 4                         8.0                 12.82                   9.0
# ...                       ...                   ...                   ...
# 79995                    19.0                 14.56                   3.0
# 79996                    19.0                  8.98                   6.0
# 79997                    13.0                 16.65                   7.0
# 79998                    16.0                  1.88                  12.0
# 79999                     9.0                  3.90                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0           Good            405.45                 32.643281
# 1            Bad           4259.91                 39.375507
# 2            Bad           3406.51                 34.039021
# 3       Standard            727.29                 34.747262
# 4       Standard            817.64                 24.545394
# ...          ...               ...                       ...
# 79995   Standard             34.09                 41.899992
# 79996        Bad           4466.33                 24.275710
# 79997   Standard           1189.37                 38.439021
# 79998        Bad           3468.25                 24.233841
# 79999       Good             79.67                 27.903216
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                   336.0                    No            77.284943
# 1                   144.0                   Yes           171.748418
# 2                   123.0                   Yes           205.403926
# 3                   129.0                   Yes            41.177132
# 4                   122.0                    NM           196.679642
# ...                   ...                   ...                  ...
# 79995               211.0                   Yes             0.000000
# 79996                98.0                    NM            64.533114
# 79997               241.0                    NM            40.264074
# 79998                85.0                   Yes           240.664739
# 79999               366.0                    No            60.567361
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    53.714219   High_spent_Large_value_payments
# 1                    44.990811   High_spent_Large_value_payments
# 2                    40.781489   High_spent_Large_value_payments
# 3                    23.005463    Low_spent_Large_value_payments
# 4                    63.346750   Low_spent_Medium_value_payments
# ...                        ...                               ...
# 79995               150.220682   High_spent_Large_value_payments
# 79996                34.457893   High_spent_Small_value_payments
# 79997                22.234178  High_spent_Medium_value_payments
# 79998                42.839562    Low_spent_Large_value_payments
# 79999                60.971467   Low_spent_Medium_value_payments
#
#        Monthly_Balance
# 0           847.172909
# 1           280.855383
# 2           247.322615
# 3           298.156832
# 4           152.669902
# ...                ...
# 79995       984.123010
# 79996       260.523798
# 79997       403.980355
# 79998       146.741586
# 79999       355.384222
#
# [80000 rows x 20 columns]

# %%
print(len(df_train["Credit_Mix"].unique())) # Type_of_Loan: 6261 tipos, dropear
                                             # meter credit_mix
# Out:
# 3

# %%
df_train.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       97384.44            8167.370000                1.0              3.0
# 1       31369.58            2607.131667                8.0              9.0
# 2       30171.86            2772.321667                6.0              7.0
# 3       13100.02            1246.668333                7.0              5.0
# 4       62313.54            5120.795000                6.0              2.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            8.0          1.0
# 1           27.0          8.0
# 2           30.0          9.0
# 3            6.0          5.0
# 4           18.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0                            Debt Consolidation Loan                 20.0
# 1  Home Equity Loan, Not Specified, Not Specified...                 30.0
# 2  Personal Loan, Home Equity Loan, Home Equity L...                 49.0
# 3  Credit-Builder Loan, Credit-Builder Loan, Not ...                  6.0
# 4  Auto Loan, Payday Loan, Student Loan, and Cred...                 27.0
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                    12.0                  0.52                   3.0
# 1                    25.0                 19.70                   6.0
# 2                    18.0                 23.49                  10.0
# 3                    20.0                 10.64                   8.0
# 4                     8.0                 12.82                   9.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            405.45                 32.643281               336.0
# 1        Bad           4259.91                 39.375507               144.0
# 2        Bad           3406.51                 34.039021               123.0
# 3   Standard            727.29                 34.747262               129.0
# 4   Standard            817.64                 24.545394               122.0
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            77.284943                53.714219
# 1                   Yes           171.748418                44.990811
# 2                   Yes           205.403926                40.781489
# 3                   Yes            41.177132                23.005463
# 4                    NM           196.679642                63.346750
#
#                  Payment_Behaviour  Monthly_Balance
# 0  High_spent_Large_value_payments       847.172909
# 1  High_spent_Large_value_payments       280.855383
# 2  High_spent_Large_value_payments       247.322615
# 3   Low_spent_Large_value_payments       298.156832
# 4  Low_spent_Medium_value_payments       152.669902

# %%
oe = OrdinalEncoder()
mm = MinMaxScaler()

df_train[['Payment_of_Min_Amount']] = oe.fit_transform(df_train[['Payment_of_Min_Amount']])

df_train[['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Num_Credit_Inquiries', 
          'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount'
          ]] = mm.fit_transform(df_train[['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 
          'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 
          'Payment_of_Min_Amount']])

"""
scaler = Compose.ColumnTransformer(transformers=[
    ("Annual_Income", MinMaxScaler(), [0]),
    ("Monthly_Inhand_Salary", MinMaxScaler(), [0]),
    ("Num_Bank_Accounts", MinMaxScaler(), [0]),
    ("Num_Credit_Card", MinMaxScaler(), [0]),
    ("Interest_Rate", MinMaxScaler(), [4]),
    ("Num_of_Loan", MinMaxScaler(), [5]),
    ("Type_of_Loan", OrdinalEncoder(), [0]),           # que hay 6200 xD
    ("Delay_From_Due_Date", MinMaxScaler(), [6]),       # quiza un poco useless
    ("Num_of_Delayed_Payments", MinMaxScaler(), [7]),
    ("Num_Credit_Inquiries", MinMaxScaler(), [8]),
    ("Outstanding_Debt", MinMaxScaler(), [9]),
    ("Credit_Utilization_Ratio", MinMaxScaler(), [10]),
    ("Credit_History_Age", MinMaxScaler(), [11]),
    ("Payment_of_Min_Amount", OrdinalEncoder(), [12])
])
"""

df_train = pd.DataFrame(df_train)
df_train
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0           0.522475               0.527732           0.090909
# 1           0.140846               0.154586           0.727273
# 2           0.133922               0.165672           0.545455
# 3           0.035230               0.063286           0.636364
# 4           0.319732               0.323277           0.545455
# ...              ...                    ...                ...
# 79995       0.582464               0.586771           0.363636
# 79996       0.053257               0.053344           0.545455
# 79997       0.129314               0.139202           0.272727
# 79998       0.212604               0.217428           0.545455
# 79999       0.550404               0.548911           0.181818
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0             0.272727       0.212121     0.111111
# 1             0.818182       0.787879     0.888889
# 2             0.636364       0.878788     1.000000
# 3             0.454545       0.151515     0.555556
# 4             0.181818       0.515152     0.444444
# ...                ...            ...          ...
# 79995         0.454545       0.242424     0.000000
# 79996         0.545455       0.606061     0.555556
# 79997         0.636364       0.151515     0.222222
# 79998         0.818182       0.727273     0.888889
# 79999         0.454545       0.272727     0.111111
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 0                                Debt Consolidation Loan             0.322581
# 1      Home Equity Loan, Not Specified, Not Specified...             0.483871
# 2      Personal Loan, Home Equity Loan, Home Equity L...             0.790323
# 3      Credit-Builder Loan, Credit-Builder Loan, Not ...             0.096774
# 4      Auto Loan, Payday Loan, Student Loan, and Cred...             0.435484
# ...                                                  ...                  ...
# 79995                                            No Data             0.112903
# 79996  Mortgage Loan, Home Equity Loan, Credit-Builde...             0.709677
# 79997                      Student Loan, and Payday Loan             0.370968
# 79998  Payday Loan, Auto Loan, Payday Loan, Home Equi...             0.516129
# 79999                                      Mortgage Loan             0.177419
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                        0.48                  0.52              0.176471
# 1                        1.00                 19.70              0.352941
# 2                        0.72                 23.49              0.588235
# 3                        0.80                 10.64              0.470588
# 4                        0.32                 12.82              0.529412
# ...                       ...                   ...                   ...
# 79995                    0.76                 14.56              0.176471
# 79996                    0.76                  8.98              0.352941
# 79997                    0.52                 16.65              0.411765
# 79998                    0.64                  1.88              0.705882
# 79999                    0.36                  3.90              0.470588
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0           Good          0.081079                  0.421443
# 1            Bad          0.852304                  0.645850
# 2            Bad          0.681550                  0.467967
# 3       Standard          0.145475                  0.491575
# 4       Standard          0.163553                  0.151513
# ...          ...               ...                       ...
# 79995   Standard          0.006775                  0.730000
# 79996        Bad          0.893606                  0.142524
# 79997   Standard          0.237931                  0.614634
# 79998        Bad          0.693904                  0.141128
# 79999       Good          0.015895                  0.263441
#
#        Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                0.831266                    0.5            77.284943
# 1                0.354839                    1.0           171.748418
# 2                0.302730                    1.0           205.403926
# 3                0.317618                    1.0            41.177132
# 4                0.300248                    0.0           196.679642
# ...                   ...                    ...                  ...
# 79995            0.521092                    1.0             0.000000
# 79996            0.240695                    0.0            64.533114
# 79997            0.595533                    0.0            40.264074
# 79998            0.208437                    1.0           240.664739
# 79999            0.905707                    0.5            60.567361
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    53.714219   High_spent_Large_value_payments
# 1                    44.990811   High_spent_Large_value_payments
# 2                    40.781489   High_spent_Large_value_payments
# 3                    23.005463    Low_spent_Large_value_payments
# 4                    63.346750   Low_spent_Medium_value_payments
# ...                        ...                               ...
# 79995               150.220682   High_spent_Large_value_payments
# 79996                34.457893   High_spent_Small_value_payments
# 79997                22.234178  High_spent_Medium_value_payments
# 79998                42.839562    Low_spent_Large_value_payments
# 79999                60.971467   Low_spent_Medium_value_payments
#
#        Monthly_Balance
# 0           847.172909
# 1           280.855383
# 2           247.322615
# 3           298.156832
# 4           152.669902
# ...                ...
# 79995       984.123010
# 79996       260.523798
# 79997       403.980355
# 79998       146.741586
# 79999       355.384222
#
# [80000 rows x 20 columns]

# %% [markdown]
# ## Entrenamiento

# %%
from sklearn.naive_bayes import GaussianNB

X = df_train[['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 
              'Num_of_Delayed_Payment', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount']]


# validacion cruzada
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

gnb = GaussianNB()


y_pred = gnb.fit(X_train, y_train).predict(X_test)


# print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))

# %% [markdown]
# ## Cosas Guarras (IGNORAR)

# %% [markdown]
# https://es.stackoverflow.com/questions/398654/como-ordenar-porcentajes-en-grafica-de-barras
#
#
#
# Plot correlation in pandas
#
# https://www.stackvidhya.com/plot-correlation-matrix-in-pandas-python/
#
#
# Tablas y cosas chulas
#
# https://relopezbriega.github.io/blog/2016/02/29/analisis-de-datos-categoricos-con-python/

# %%
# GUARRADAS Y PRUEBAS GUARRAS

# %%
# Month
# Representa el mes del año en el que se actualizó la información
# 
plot = (100 * df_train['Annual_Income'].value_counts() / len(df_train['Annual_Income'])).plot(
kind='bar', title='aaaa %')

# %%
plot = df_train['Age'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Pasajeros del Titanic')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-ac3d39384dc2> in <module>
# ----> 1 plot = df_train['Age'].value_counts().plot(kind='pie', autopct='%.2f',
#       2                                             figsize=(6, 6),
#       3                                             title='Pasajeros del Titanic')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Age'
